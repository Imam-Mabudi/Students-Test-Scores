# %% [markdown]
# #  Introduction
# In this notebook, we will perform exploratory data analysis (EDA) and data visualization on the Student Test Scores dataset. The dataset contains information about students' demographic backgrounds and test scores.
#
# **The objectives of this notebook are:**
#
# * To explore the relationships between different variables in the dataset
# * To identify trends and patterns in the data
# * To visualize the data using various plotting techniques
# * To gain insights that can help us build predictive models for student test scores
# * Let's start by importing the necessary libraries and loading the dataset.

# %% [markdown]
# ## Data dictionary
# The following are the column descriptions. Columns 0 to 5 and 11 to 13 are common to both files. The rest are present to the extended file only.
#
# 1. Gender: gender of the student (male/female)
#
# 1. EthnicGroup: ethnic group of the student (group A to E)
#
# 1. ParentEduc: parent(s) education background
#
# 1. LunchType: school luch type (standard or free/reduced)
#
# 1. TestPrep: test preparation course (completed or none)
#
# 1. ParentMaritalStatus: parent(s) marital status
#
# 1. PracticeSport: how often the student parctice sport
#
# 1. IsFirstChild: if the child is first child in the family or not
#
# 1. NrSiblings : Number of siblings the student has
#
# 1. TransportMeans: Means of transport to school
#
# 1. WklyStudyHours: Weekly self-study hours
#
# 1. MathScore: math test score
#
# 1. ReadingScore: reading test score
#
# 1. WritingScore writing test score

# %% [markdown]
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
data = pd.read_csv('Expanded_data.csv')

# %%
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %%
data.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
data.transpose()
# Out:
#                                  0             1                2      \
# Unnamed: 0                           0             1                2
# Gender                          female        female           female
# EthnicGroup                        NaN       group C          group B
# ParentEduc           bachelor's degree  some college  master's degree
# LunchType                     standard      standard         standard
# TestPrep                          none           NaN             none
# ParentMaritalStatus            married       married           single
# PracticeSport                regularly     sometimes        sometimes
# IsFirstChild                       yes           yes              yes
# NrSiblings                         3.0           0.0              4.0
# TransportMeans              school_bus           NaN       school_bus
# WklyStudyHours                     < 5        5 - 10              < 5
# MathScore                           71            69               87
# ReadingScore                        71            90               93
# WritingScore                        74            88               91
#
#                                   3             4                   5      \
# Unnamed: 0                            3             4                   5
# Gender                             male          male              female
# EthnicGroup                     group A       group C             group B
# ParentEduc           associate's degree  some college  associate's degree
# LunchType                  free/reduced      standard            standard
# TestPrep                           none          none                none
# ParentMaritalStatus             married       married             married
# PracticeSport                     never     sometimes           regularly
# IsFirstChild                         no           yes                 yes
# NrSiblings                          1.0           0.0                 1.0
# TransportMeans                      NaN    school_bus          school_bus
# WklyStudyHours                   5 - 10        5 - 10              5 - 10
# MathScore                            45            76                  73
# ReadingScore                         56            78                  84
# WritingScore                         42            75                  79
#
#                             6             7             8             9      \
# Unnamed: 0                      6             7             8             9
# Gender                     female          male          male        female
# EthnicGroup               group B       group B       group D       group B
# ParentEduc           some college  some college   high school   high school
# LunchType                standard  free/reduced  free/reduced  free/reduced
# TestPrep                completed          none     completed          none
# ParentMaritalStatus       widowed       married        single       married
# PracticeSport               never     sometimes     sometimes     regularly
# IsFirstChild                   no           yes            no           yes
# NrSiblings                    1.0           1.0           3.0           NaN
# TransportMeans            private       private       private       private
# WklyStudyHours             5 - 10          > 10          > 10           < 5
# MathScore                      85            41            65            37
# ReadingScore                   93            43            64            59
# WritingScore                   89            39            68            50
#
#                      ...             30631         30632            30633  \
# Unnamed: 0           ...               765           778              783
# Gender               ...              male        female           female
# EthnicGroup          ...           group E       group D          group C
# ParentEduc           ...  some high school  some college  master's degree
# LunchType            ...          standard      standard         standard
# TestPrep             ...              none          none        completed
# ParentMaritalStatus  ...           married       married          married
# PracticeSport        ...         sometimes     regularly            never
# IsFirstChild         ...                no            no               no
# NrSiblings           ...               3.0           3.0              2.0
# TransportMeans       ...        school_bus       private       school_bus
# WklyStudyHours       ...               < 5        5 - 10           5 - 10
# MathScore            ...                80            82               84
# ReadingScore         ...                65            88               99
# WritingScore         ...                66            97               99
#
#                                   30634         30635        30636  \
# Unnamed: 0                          785           794          816
# Gender                             male          male       female
# EthnicGroup                     group A       group C      group D
# ParentEduc           associate's degree  some college  high school
# LunchType                  free/reduced      standard     standard
# TestPrep                      completed          none         none
# ParentMaritalStatus                 NaN       married       single
# PracticeSport                 sometimes     regularly    sometimes
# IsFirstChild                         no            no           no
# NrSiblings                          2.0           2.0          2.0
# TransportMeans               school_bus    school_bus   school_bus
# WklyStudyHours                   5 - 10        5 - 10       5 - 10
# MathScore                            65            58           59
# ReadingScore                         60            53           61
# WritingScore                         60            49           65
#
#                            30637         30638               30639  \
# Unnamed: 0                   890           911                 934
# Gender                      male        female              female
# EthnicGroup              group E           NaN             group D
# ParentEduc           high school   high school  associate's degree
# LunchType               standard  free/reduced            standard
# TestPrep                    none     completed           completed
# ParentMaritalStatus       single       married             married
# PracticeSport          regularly     sometimes           regularly
# IsFirstChild                  no            no                  no
# NrSiblings                   1.0           1.0                 3.0
# TransportMeans           private       private          school_bus
# WklyStudyHours            5 - 10        5 - 10              5 - 10
# MathScore                     58            61                  82
# ReadingScore                  53            70                  90
# WritingScore                  51            67                  93
#
#                             30640
# Unnamed: 0                    960
# Gender                       male
# EthnicGroup               group B
# ParentEduc           some college
# LunchType                standard
# TestPrep                     none
# ParentMaritalStatus       married
# PracticeSport               never
# IsFirstChild                   no
# NrSiblings                    1.0
# TransportMeans         school_bus
# WklyStudyHours             5 - 10
# MathScore                      64
# ReadingScore                   60
# WritingScore                   58
#
# [15 rows x 30641 columns]

# %%
data.count()
# Out:
# Unnamed: 0             30641
# Gender                 30641
# EthnicGroup            28801
# ParentEduc             28796
# LunchType              30641
# TestPrep               28811
# ParentMaritalStatus    29451
# PracticeSport          30010
# IsFirstChild           29737
# NrSiblings             29069
# TransportMeans         27507
# WklyStudyHours         29686
# MathScore              30641
# ReadingScore           30641
# WritingScore           30641
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# There are alot of missing data

# %% [markdown]
# ## Data cleaning

# %%
#dropping the column Unnamed

data = data.drop('Unnamed: 0', axis=1)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female         NaN   bachelor's degree      standard       none
# 1      female     group C        some college      standard        NaN
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 1                 married     sometimes          yes         0.0
# 2                  single     sometimes          yes         4.0
# 3                 married         never           no         1.0
# 4                 married     sometimes          yes         0.0
# ...                   ...           ...          ...         ...
# 30636              single     sometimes           no         2.0
# 30637              single     regularly           no         1.0
# 30638             married     sometimes           no         1.0
# 30639             married     regularly           no         3.0
# 30640             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %% [markdown]
# Dropping the column Unknown it seems not to have any useful data for analysis.

# %%
# renaming and editing some column names

data.rename(columns = {'IsFirstChild':'First_Child', 'NrSiblings':'Siblings_Number', 'EthnicGroup':'Ethnic_Group', 'ParentEduc':'Parent_Education', 'LunchType':'Lunch_Type', 'TestPrep':'Test_Prep', 'ParentMaritalStatus':'Parent_Marital_Status', 'PracticeSport':'Practice_Sport', 'ReadingScore':'Reading_Score', 'WritingScore':'Writing_Score', 'TransportMeans':'Transport_Means', 'WklyStudyHours':'Weekly_Study_Hours', 'MathScore':'Math_Score'   }, inplace = True)

# %%
data.columns
# Out:
# Index(['Gender', 'Ethnic_Group', 'Parent_Education', 'Lunch_Type', 'Test_Prep',
#        'Parent_Marital_Status', 'Practice_Sport', 'First_Child',
#        'Siblings_Number', 'Transport_Means', 'Weekly_Study_Hours',
#        'Math_Score', 'Reading_Score', 'Writing_Score'],
#       dtype='object')

# %%
data
# Out:
#        Gender Ethnic_Group    Parent_Education    Lunch_Type  Test_Prep  \
# 0      female          NaN   bachelor's degree      standard       none
# 1      female      group C        some college      standard        NaN
# 2      female      group B     master's degree      standard       none
# 3        male      group A  associate's degree  free/reduced       none
# 4        male      group C        some college      standard       none
# ...       ...          ...                 ...           ...        ...
# 30636  female      group D         high school      standard       none
# 30637    male      group E         high school      standard       none
# 30638  female          NaN         high school  free/reduced  completed
# 30639  female      group D  associate's degree      standard  completed
# 30640    male      group B        some college      standard       none
#
#       Parent_Marital_Status Practice_Sport First_Child  Siblings_Number  \
# 0                   married      regularly         yes              3.0
# 1                   married      sometimes         yes              0.0
# 2                    single      sometimes         yes              4.0
# 3                   married          never          no              1.0
# 4                   married      sometimes         yes              0.0
# ...                     ...            ...         ...              ...
# 30636                single      sometimes          no              2.0
# 30637                single      regularly          no              1.0
# 30638               married      sometimes          no              1.0
# 30639               married      regularly          no              3.0
# 30640               married          never          no              1.0
#
#       Transport_Means Weekly_Study_Hours  Math_Score  Reading_Score  \
# 0          school_bus                < 5          71             71
# 1                 NaN             5 - 10          69             90
# 2          school_bus                < 5          87             93
# 3                 NaN             5 - 10          45             56
# 4          school_bus             5 - 10          76             78
# ...               ...                ...         ...            ...
# 30636      school_bus             5 - 10          59             61
# 30637         private             5 - 10          58             53
# 30638         private             5 - 10          61             70
# 30639      school_bus             5 - 10          82             90
# 30640      school_bus             5 - 10          64             60
#
#        Writing_Score
# 0                 74
# 1                 88
# 2                 91
# 3                 42
# 4                 75
# ...              ...
# 30636             65
# 30637             51
# 30638             67
# 30639             93
# 30640             58
#
# [30641 rows x 14 columns]

# %%
data.dtypes
# Out:
# Gender                    object
# Ethnic_Group              object
# Parent_Education          object
# Lunch_Type                object
# Test_Prep                 object
# Parent_Marital_Status     object
# Practice_Sport            object
# First_Child               object
# Siblings_Number          float64
# Transport_Means           object
# Weekly_Study_Hours        object
# Math_Score                 int64
# Reading_Score              int64
# Writing_Score              int64
# dtype: object

# %%
data['Siblings_Number'] = data['Siblings_Number'].fillna(0).astype(int)
data['Weekly_Study_Hours'] = pd.to_numeric(data['Weekly_Study_Hours'], errors='coerce')

# %%
data.dtypes
# Out:
# Gender                    object
# Ethnic_Group              object
# Parent_Education          object
# Lunch_Type                object
# Test_Prep                 object
# Parent_Marital_Status     object
# Practice_Sport            object
# First_Child               object
# Siblings_Number            int32
# Transport_Means           object
# Weekly_Study_Hours       float64
# Math_Score                 int64
# Reading_Score              int64
# Writing_Score              int64
# dtype: object

# %% [markdown]
# From the **data.dtypes** output, we can see that some columns have an incorrect data type. Specifically, **NrSiblings** should have a data type of int instead of float, and **WklyStudyHours** should also have a numeric data type instead of an object.

# %% [markdown]
# ## Data Visualization

# %%
# plot the distribution of the gender variable
sns.countplot(x='Gender', data=data)
plt.show()

# %% [markdown]
# Male and female have almost an equal distribution

# %%
# Bar chart of EthnicGroup column

plt.figure(figsize=(8,6))
data['Ethnic_Group'].value_counts().plot(kind='bar')
plt.xlabel('Ethnic Group')
plt.ylabel('Count')
plt.title('Distribution of Ethnic Groups')
plt.show()

# %% [markdown]
# Group c has the overall total distribution in ethnic group

# %%
# Bar chart of Parent_Education column
plt.figure(figsize=(8,4))
data['Parent_Education'].value_counts().plot(kind='bar')
plt.xlabel('Parent Education Level')
plt.ylabel('Count')
plt.title('Distribution of Parent Education Levels')
plt.show()

# %% [markdown]
# Parents that have some college certificate are more populated in the Parent_Education_Level and the least certificate holders are the masters degree.

# %%
# Bar chart of Lunch_Type column
plt.figure(figsize=(8,6))
data['Lunch_Type'].value_counts().plot(kind='bar')
plt.xlabel('Lunch Type')
plt.ylabel('Count')
plt.title('Distribution of Lunch Types')
plt.show()

# %% [markdown]
# Standard lunch type are more subcribed than free/reduced lunch type.

# %%
# Bar chart of Test_Prep column
plt.figure(figsize=(8,6))
data['Test_Prep'].value_counts().plot(kind='bar')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.title('Distribution of Test Preparation Courses')
plt.show()

# %% [markdown]
# Majority of the student are not prepared to carry the test course.

# %%
# Bar chart of ParentMaritalStatus column
plt.figure(figsize=(8,6))
data['Parent_Marital_Status'].value_counts().plot(kind='bar')
plt.xlabel('Parent Marital Status')
plt.ylabel('Count')
plt.title('Distribution of Parent Marital Status')
plt.show()

# %% [markdown]
# Most of the student parents are married.

# %%
# Bar chart of PracticeSport column

plt.figure(figsize=(8,6))
data['Practice_Sport'].value_counts().plot(kind='bar')
plt.xlabel('Frequency of Practicing Sports')
plt.ylabel('Count')
plt.title('Distribution of Frequency of Practicing Sports')
plt.show()

# %% [markdown]
# The frequency status of sports need to be improved from sometimes to regularly.

# %%
# Bar chart of First_Child column

plt.figure(figsize=(8,6))
data['First_Child'].value_counts().plot(kind='bar')
plt.xlabel('First Child?')
plt.ylabel('Count')
plt.title('Distribution of IF Student is First Child')
plt.show()

# %% [markdown]
# Majority of the students are first child.

# %%
# Histogram of Weekly_Study_Hours column

plt.style.use('dark_background')
plt.title('Distribution of Weekly Self-Study Hours')
plt.ylabel('Count')
#data['Weekly_Study_Hours'].hist()
plt.plot(['Weekly_Study_Hours'])

# %%
# Histogram of Reading_Score column

plt.style.use('Solarize_Light2')

plt.xlabel('Math Test Score')

plt.ylabel('Count')

data['Math_Score'].hist()
# Out:
# <AxesSubplot:xlabel='Math Test Score', ylabel='Count'>

# %% [markdown]
# * The minimum math score is 0, while the minimum reading score is 10 and the minimum writing score is 4, which suggests that some students scored very low on these tests.
# * The 25th percentile for the math, reading, and writing scores are around 56-59, which indicates that 25% of the students scored below this level.
# * The 50th percentile (median) for the math, reading, and writing scores are around 67-70, which indicates that 50% of the students scored below this level.
# * The 75th percentile for the math, reading, and writing scores are around 78-80, which indicates that 25% of the students scored above this level.
# * The maximum math score is 100, while the maximum reading and writing scores are also 100, which suggests that some students scored very high on these tests.

# %%
# Histogram of Reading_Score column

plt.figure(figsize=(6,4))
data['Reading_Score'].hist(bins=20)
plt.style.use('dark_background')

plt.xlabel('Reading Test Score')
plt.ylabel('Count')
plt.title('Distribution of Reading Test Scores')
plt.show()

# %% [markdown]
# * The maximum reading score is 60, followed by 80, the minimum reading score is 0

# %%
# Histogram of Writing_Score column

plt.figure(figsize=(6,4))
data['Writing_Score'].hist(bins=20)
plt.xlabel('Writing Test Score')
plt.style.use('dark_background')
plt.ylabel('Count')
plt.title('Distribution of Writing Test Scores')
plt.show()

# %% [markdown]
# * The minimum writing score is 0, the maximum is 60 t0 65, followed by 80 score.

# %%
# plot the relationship between math_score and reading_score

sns.scatterplot(x='Math_Score', y='Reading_Score', data=data)
plt.show()

# %%
gender_counts = data['Gender'].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_counts
# Out:
# female    15424
# male      15217
# Name: Gender, dtype: int64

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr
# Out:
#                     Siblings_Number  Weekly_Study_Hours  Math_Score  \
# Siblings_Number            1.000000                 NaN   -0.000008
# Weekly_Study_Hours              NaN                 NaN         NaN
# Math_Score                -0.000008                 NaN    1.000000
# Reading_Score             -0.000039                 NaN    0.817825
# Writing_Score             -0.000799                 NaN    0.807118
#
#                     Reading_Score  Writing_Score
# Siblings_Number         -0.000039      -0.000799
# Weekly_Study_Hours            NaN            NaN
# Math_Score               0.817825       0.807118
# Reading_Score            1.000000       0.952584
# Writing_Score            0.952584       1.000000
